# %% [markdown]
# # Bookings held longer on detainer than on other charges
#
# Here we're looking for bookings where the charge release date for immigration hold was greater than release date for other charges. Note that charge release dates may be later than actual release dates. What we're looking for is records where actual release date and hold release date are both later than release dates for other charges. Could consider adding additional logic below to control for this but for now we'll hand check.

# %%
import pandas as pd
import numpy as np

# %%
path = '../input/'
df = pd.read_csv(f'{path}pierce.csv.gz', sep='|', compression='gzip', low_memory=False)

# %%
df['booking_dt'] = pd.to_datetime(df['booking_dt'])
df['release_dt'] = pd.to_datetime(df['release_dt'])
df['charge_release_dt'] = pd.to_datetime(df['charge_release_dt'])

# %%
hold_ids = df[df['imm_hold'] == 1]['booking_id_hash'].tolist()

# %%
df['release_dt']= pd.to_datetime(df['release_dt'])
df['charge_release_dt'] = pd.to_datetime(df['charge_release_dt'])

df['charge_delta'] = df['charge_release_dt'] - df['booking_dt']
df['charge_delta'] = df['charge_delta'] / np.timedelta64(1,'h') 

df['charge_release_delta'] = df['charge_release_dt'] - df['release_dt']
df['charge_release_delta'] = df['charge_release_delta'] / np.timedelta64(1,'h')

held_longer_on_detainer = []
how_much_longer = []
for b_id in hold_ids:
    booking = df[df['booking_id_hash'] == b_id]

    non_hold_charge_deltas = booking[booking['booking_charge_desc'] != 'HOLD IMMIGRAT']['charge_delta']

    hold_charge_delta = float(booking[booking['booking_charge_desc'] == 'HOLD IMMIGRAT']['charge_delta'])
    
    hold_release_delta = float(booking[booking['booking_charge_desc'] == 'HOLD IMMIGRAT']['charge_release_delta'])
    
    if hold_charge_delta > non_hold_charge_deltas.max():
        
        held_longer_on_detainer.append(b_id)
    
    how_much_longer.append([hold_charge_delta - non_hold_charge_deltas.max(), hold_release_delta, b_id])

# df[df['booking_id_hash'].isin(held_longer_on_detainer)].to_csv('../output/held_longer_on_detainer.csv', index=False)

# %%
held_longer_on_detainer_df = df[df['booking_id_hash'].isin(held_longer_on_detainer)]

# %%
len(set(held_longer_on_detainer_df['booking_id_hash']))
# Out:
# 45

# %%
temp = pd.DataFrame(how_much_longer, columns=['longer_than_other_charge', 'longer_than_release', 'booking_id_hash']).drop_duplicates()

# %%
temp['longer_than_other_charge'].mean()
# Out:
# 12.424556737588654

# %%
temp['longer_than_release'].mean()
# Out:
# -10.518794326241137

# %%
temp
# Out:
#      longer_than_other_charge  longer_than_release  \
# 0                    9.000000             3.000000
# 8                   -1.000000            -1.000000
# 13                   0.000000            -0.750000
# 18                   0.000000             0.000000
# 23                   2.500000            -0.166667
# 30                   0.000000            -2.000000
# 38                   0.000000             0.000000
# 41                  -0.500000             0.000000
# 46                   0.000000             0.000000
# 49                   0.000000             0.000000
# 52                   4.516667            -0.216667
# 55                   0.000000             0.000000
# 57                   1.150000             0.000000
# 60                   0.000000             0.000000
# 67                  -3.000000            -0.083333
# 69                   0.000000             0.500000
# 74                   0.000000             0.000000
# 84                   0.750000             0.000000
# 89                  76.000000             2.916667
# 91                   0.000000            -2.000000
# 94                  15.983333             0.183333
# 96                   0.000000            -0.166667
# 102                  0.000000             0.000000
# 106                 -2.000000            -0.166667
# 568  4a6dca40e57a996a4c4f87d5a044c6905e798f35
# 571  a9ca7d208e99b57524f293a1f2c5996f31f32e41
# 574  2dcb7d4d9faa2556d95c1c336976bbc3d50c8e55
# 576  2cc77d1e1325dafcae61e4d50dba7d3647f174df
# 580  2becdfac14ed7da8d98c0c0528abc7bfd9eca4a8
# 582  b8f9e089d82cfcf6c7619b36e3c379a6bd936cf1
# 587  c6f198f0e2ae040890509afdc8576ef7ba5d010c
# 589  117fcf8ad630d42f017b76b40be608e0c2fca5e4
# 594  5433af88577f44cf36c64a9360400fb1c0629dbd
# 596  aa55ae8593812ab4971d516d78ef8a15b0f3175e
# 599  538dc84568a33476437d88aa5890e56da47cfbff
# 603  d9f177cdae08a5cc1cebbb53b54fbc0cbbe4cff8
# 611  c550e855f79372c3fd449093415bc6f9f2f3b880
# 615  faee4990f808cb492c3dc3acddedb8e40f4cb166
# 617  685dbbfaadb6e41ec263f59495c41599bb807722
# 620  4664c6781363cc7e033adc604f3c8fe045460b04
# 626  e0d83cde4b827dcf67348ee5df452009d41810a6
# 630  69abe78818d8a4f918c765e58c18368f93973f74
# 637  7b3115893d9bf6dbfdaea6857731f7544a43fd54
# 639  eb4ca0b14bb3a322ab49f8b50297e65842b73865
# 642  983f4d61e0465fb63d3922032e533b5de652bf76
# 645  616cf0070dbe3a0de7a4ad3bec1e40bf5926a707
# 649  0ab27bce992a5f6e7691c579d64a8f55e59208ed
# 652  6a68214750c62a36da89816324247460d7730ab0
# 659  ec97201aa8292e044a398982c21f7667fa152242
# 661  e9df8dd29811d7001fcb72a3629301cf10e9a3ec
# 663  c0d6c552b796b3f0b5d3d430871621ebe388a351
# 665  0c6b51dc8bbcfd8f52759552584f7a9ba105255b
#
# [188 rows x 3 columns]

# %%
hold_df = df[df['imm_hold'] == 1]

# %%
hold_df = pd.merge(hold_df, temp, on='booking_id_hash')

# %%
hold_df[['booking_dt', 'release_dt', 'booking_charge_desc', 'charge_release_dt', 'cause_num', 'release_disposition_desc', 'gender_desc', 'race_desc']].head()
# Out:
#            booking_dt          release_dt      booking_charge_desc  \
# 0 2015-12-22 08:21:00 2018-04-19 14:00:00      THFT OF FIREARM (B)
# 1 2015-12-22 08:21:00 2018-04-19 14:00:00  TRAFFICKING STOL PROP 1
# 2 2015-12-22 08:21:00 2018-04-19 14:00:00  TRAFFICKING STOL PROP 1
# 3 2015-12-22 08:21:00 2018-04-19 14:00:00            HOLD IMMIGRAT
# 4 2015-12-22 08:21:00 2018-04-19 14:00:00                 HOLD WSI
#
#     charge_release_dt     cause_num release_disposition_desc gender_desc  \
# 0 2018-04-18 12:00:00  12-1-00068-1                Dismissed        MALE
# 1 2018-04-18 12:00:00  12-1-00068-1                Dismissed        MALE
# 2 2018-04-18 12:00:00  12-1-00068-1                Dismissed        MALE
# 3 2018-04-19 17:00:00           NaN              Immigration        MALE
# 4 2018-04-19 08:00:00           NaN          Cancel Detainer        MALE
#
#               race_desc
# 0  ASIAN/PACIFIC ISLAND
# 1  ASIAN/PACIFIC ISLAND
# 2  ASIAN/PACIFIC ISLAND
# 574 2018-03-29 16:10:00 2018-04-23 09:52:00
# 580 2018-04-01 02:05:00 2018-06-20 09:35:00
# 587 2018-04-13 03:25:00 2018-04-16 17:00:00
# 596 2018-04-30 04:07:00 2018-06-29 08:56:00
# 639 2018-06-15 03:08:00 2018-07-12 18:55:00
# 661 2018-07-13 15:26:00 2018-07-16 15:50:00
#
#                     booking_charge_desc booking_charge_txt  \
# 0                   THFT OF FIREARM (B)                NaN
# 23                        HIT/RUN UNATT                NaN
# 52                               ASLT 1                NaN
# 57                        HOLD IMMIGRAT                NaN
# 84                        HOLD IMMIGRAT                NaN
# 89                        HOLD IMMIGRAT                NaN
# 94                        ASSAULT 4 /DV                NaN
# 133                       RECK ENDANGER                NaN
# 138                              RAPE 2          ATTEMPTED
# 146              POSSESS STOLEN VEHICLE                NaN
# 154                      HARASSMENT /DV                NaN
# 161                       HOLD IMMIGRAT                NaN
# 176                       HOLD IMMIGRAT                NaN
# 179                       HOLD IMMIGRAT                NaN
# 181                         NEG DRIVING                NaN
# 217                              ASLT 2                NaN
# 276                       CRIM ASLT /DV                NaN
# 279                       HOLD IMMIGRAT                NaN
# 287  MTR VEH TRANSFER OF OWNERSHIP VIOL                NaN
# 303                       HOLD IMMIGRAT                NaN
# 318                       UPCS W INTENT                NaN
# 327                                 DWI                NaN
# 336                       DEST PROP /DV                NaN
# 349                       HOLD IMMIGRAT                NaN
# 357                       HOLD IMMIGRAT                NaN
# 383                       HOLD IMMIGRAT                NaN
# 409                       HOLD IMMIGRAT                NaN
# 427                            TMVWOP 2                NaN
# 429                           DWLS/DWLR                NaN
# 440                                 DWI                NaN
# 449                       HOLD IMMIGRAT                NaN
# 451                       HOLD IMMIGRAT                NaN
# 472                      OBSTR PUB SERV                NaN
# 478                       HOLD IMMIGRAT                NaN
# 501                                UPCS                NaN
# 520                  EXPOSE MINOR TO DV                NaN
# 524                                 DWI                NaN
# 541                           DWLS/DWLR                3RD
# 568                  UNL POSS FIREARM 1                NaN
# 574                            FUGITIVE              FTRSO
# 580                       UPCS W INTENT                NaN
# 587           DUI WITH PRIOR CONVICTION                NaN
# 596             DUI W/ PRIOR CONVICTION                NaN
# 639                  ILL DRUG COND/PARA                NaN
# 661                                 DWI                NaN
#
#       charge_release_dt                                          title_txt  \
# 0   2018-04-18 12:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 23  2016-07-07 08:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 52  2017-05-03 11:59:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 57  2016-10-20 13:05:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 84  2016-12-15 08:45:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 89  2016-11-15 12:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 94  2016-11-04 08:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 133 2017-05-16 17:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 138 2018-04-04 14:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 146 2017-05-02 17:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 154 2017-05-08 15:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 161 2017-01-31 10:20:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 176 2017-06-28 13:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 179 2017-05-23 08:30:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 181 2017-02-21 08:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 217 2017-04-06 08:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 276 2017-05-08 15:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 279 2017-05-08 17:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 287 2017-05-10 17:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 303 2017-05-09 18:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 318 2017-08-16 11:21:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 327 2017-05-22 15:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 336 2017-06-08 15:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 349 2017-07-24 13:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 357 2017-07-18 15:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 383 2017-07-20 23:55:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 409 2017-07-27 22:00:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 427 2017-09-20 11:29:00  Report Criteria: 10/01/2016 to 09/30/2017, Dis...
# 429 2017-08-14 22:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 440 2017-09-05 08:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 449 2017-11-13 09:01:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 451 2018-01-09 20:30:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 472 2017-11-20 15:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 478 2018-01-12 07:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 501 2018-05-31 12:41:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 520 2017-12-11 20:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 524 2018-02-08 15:18:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 541 2018-02-22 12:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 568 2018-03-20 17:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 574 2018-04-20 15:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 580 2018-06-20 08:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 587 2018-04-16 15:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 596 2018-06-29 08:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 639 2018-06-18 21:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# 661 2018-07-16 20:00:00  Report Criteria: 10/01/2017 to 07/31/2018, Dis...
#
#         cause_num jurisdiction_cd release_disposition_desc post_flg  \
# 0    12-1-00068-1             SUP                Dismissed        N
# 23        B250561            TACM              Time Served        N
# 52   16-1-03191-1             SUP   Credit for Time Served        N
# 57            NaN             IMM              Immigration        N
# 84            NaN             IMM              Immigration        N
# 89            NaN             IMM              Immigration        N
# 94      6ZC002709             PD1              Time Served        N
# 133  17-1-00164-5             SUP                Dismissed        N
# 138  17-1-00189-1             SUP                Dismissed        N
# 146  16-1-02424-8             SUP   Credit for Time Served        N
# 154       15L1383             LKM       Suspended Sentence        N
# 161           NaN             IMM              Immigration        N
# 176           NaN             IMM              Immigration        N
# 179           NaN             IMM              Immigration        N
# 181     8YC004843             PD1              Time Served        Y
# 217  16-1-02475-2             SUP              Time Served        N
# 276        D49021            TACM                       PR        N
# 279           NaN             IMM              Immigration        N
# 287     6Z0017348             LKM       Suspended Sentence        N
# 303           NaN             IMM              Immigration        N
# 318  17-1-01976-5             SUP   Credit for Time Served        N
# 327       B255502            TACM                       PR        N
# 336     D00049075            TACM                Dismissed        N
# 349           NaN             IMM              Immigration        N
# 357           NaN             IMM              Immigration        N
# 383           NaN             IMM              Immigration        N
# 409           NaN             IMM              Immigration        N
# 427  17-1-03070-0             SUP   Credit for Time Served        N
# 429           NaN             SUP                NCF Final        N
# 440     4ZC000648             PD1              Time Served        Y
# 449           NaN             IMM              Immigration        N
# 451           NaN             IMM              Immigration        N
# 472  17-1-03601-5             SUP                Dismissed        N
# 478           NaN             IMM              Extradition        N
# 501  17-1-03901-4             SUP   Credit for Time Served        N
# 520           NaN             SUP                NCF Final        N
# 524     3ZC004470             PD1   Credit for Time Served        N
# 541           NaN             PD1         NCF, Pending Inv        N
# 568           NaN             SUP         NCF, Pending Inv        N
# 574  18-1-01243-2             SUP                Dismissed        N
# 580  18-1-01258-1             SUP              Time Served        N
# 587           NaN             PD1         NCF, Pending Inv        N
# 596     B00257007            TACM              Time Served        N
# 639           NaN            TACM                NCF Final        N
# 661     4ZC000565             PD1                       PR        N
#
#             ...          violent felony misdemeanor total_fine  paid_bail  \
# 0           ...                0      1           0        0.0      False
# 23          ...                0      1           0        0.0      False
# 52          ...                1      1           0        0.0      False
# 57          ...                0      1           0        0.0      False
# 84          ...                0      1           0        0.0      False
# 89          ...                0      0           1        0.0      False
# 94          ...                1      1           0        0.0      False
# 133         ...                1      1           0        0.0      False
# 138         ...                0      1           0        0.0      False
# 146         ...                0      1           0        0.0      False
# 154         ...                1      1           0        0.0      False
# 161         ...                0      0           1        0.0      False
# 176         ...                0      1           0        0.0      False
# 179         ...                0      0           1        0.0      False
# 181         ...                0      0           1        0.0      False
# 217         ...                1      1           0        0.0      False
# 276         ...                1      1           0        0.0      False
# 279         ...                0      0           1        0.0      False
# 287         ...                1      1           0        0.0      False
# 303         ...                0      0           1        0.0      False
# 318         ...                0      1           0        0.0      False
# 327         ...                0      0           1        0.0      False
# 336         ...                0      1           0        0.0      False
# 349         ...                0      0           1        0.0      False
# 357         ...                0      1           0        0.0      False
# 383         ...                0      1           0        0.0      False
# 409         ...                0      1           0        0.0      False
# 427         ...                0      1           0        0.0      False
# 429         ...                1      1           0        0.0      False
# 440         ...                0      0           1        0.0      False
# 449         ...                0      1           0        0.0      False
# 451         ...                0      1           0        0.0      False
# 472         ...                0      1           0        0.0      False
# 478         ...                0      1           0        0.0      False
# 501         ...                0      1           0        0.0      False
# 520         ...                1      1           0        0.0      False
# 524         ...                0      0           1        0.0      False
# 541         ...                0      1           0        0.0      False
# 568         ...                0      1           0        0.0      False
# 574         ...                0      1           0        0.0      False
# 580         ...                0      1           0        0.0      False
# 587         ...                0      1           0        0.0      False
# 596         ...                0      1           0        0.0      False
# 639         ...                0      0           0        0.0      False
# 661         ...                0      0           1        0.0      False
#
#      log_total_fine  charge_delta  charge_release_delta  \
# 0               NaN  20355.650000            -26.000000
# 23              NaN    921.766667          -8810.666667
# 52              NaN   6470.883333             -4.733333
# 57              NaN   1052.316667              0.000000
# 84              NaN   1951.166667              0.000000
# 89              NaN   1029.633333              2.916667
# 94              NaN    271.716667            -15.800000
# 133             NaN   2972.600000          -1360.500000
# 138             NaN  10689.466667             -0.416667
# 146             NaN   2328.733333             -0.516667
# 154             NaN   2458.350000           -451.000000
# 161             NaN     54.666667              0.000000
# 176             NaN   3491.300000              0.333333
# 179             NaN   2589.816667              0.000000
# 181             NaN    309.400000             -1.050000
# 217             NaN    551.016667            -32.666667
# 276             NaN     79.900000             -1.166667
# 279             NaN     64.500000              0.833333
# 287             NaN     93.200000          -2544.500000
# 303             NaN     20.666667              1.750000
# 318             NaN   2157.750000             -1.900000
# 327             NaN     38.383333             -2.666667
# 336             NaN    375.266667             -1.000000
# 349             NaN   1115.566667              0.666667
# 357             NaN    747.700000             -2.750000
# 383             NaN    505.233333             -0.500000
# 409             NaN     29.366667              2.833333
# 427             NaN    912.316667             -1.016667
# 429             NaN     24.000000          -4375.500000
# 440             NaN    447.050000          -1413.883333
# 449             NaN   1847.050000              0.183333
# 451             NaN   3187.250000              0.116667
# 472             NaN   1497.200000             -0.833333
# 478             NaN   2442.266667              0.000000
# 501             NaN   4796.650000             -3.283333
# 520             NaN     88.400000          -1218.500000
# 524             NaN   1270.683333           -224.700000
# 541             NaN     31.050000             -2.500000
# 568             NaN     24.200000             -1.000000
# 574             NaN    526.833333            -66.866667
# 580             NaN   1925.916667             -1.583333
# 587             NaN     83.583333             -2.000000
# 596             NaN   1443.883333             -0.933333
# 639             NaN     89.866667           -573.916667
# 661             NaN     76.566667              4.166667
#
#      longer_than_other_charge  longer_than_release
# 0                    9.000000             3.000000
# 23                   2.500000            -0.166667
# 52                   4.516667            -0.216667
# 57                   1.150000             0.000000
# 84                   0.750000             0.000000
# 89                  76.000000             2.916667
# 94                  15.983333             0.183333
# 133                  2.000000             0.500000
# 138                  0.416667             0.000000
# 146                  3.000000             2.483333
# 154                  2.000000             0.000000
# 161                 19.333333             0.000000
# 176                  1.700000             0.333333
# 179                  0.500000             0.000000
# 181                  1.050000             0.000000
# 217                  2.983333             0.333333
# 276                  2.000000             0.833333
# 279                  2.000000             0.833333
# 287                  7.000000             4.500000
# 303                  3.000000             1.750000
# 318                  2.150000             0.250000
# 327                  3.000000             0.333333
# 336                  3.000000             2.000000
# 349                  2.466667             0.666667
# 357                  2.166667            -2.750000
# 383                  2.916667            -0.500000
# 409                  2.000000             2.833333
# 427                  1.016667             0.000000
# 429                993.000000             0.500000
# 440               1416.000000             2.116667
# 449                 89.433333             0.183333
# 451                  6.150000             0.116667
# 472                  0.750000            -0.083333
# 478               1631.000000             0.000000
# 501                 11.300000             8.016667
# 520                  1.066667             0.500000
# 524                225.000000             6.000000
# 541                  2.500000             0.000000
# 568                  0.083333            -0.916667
# 574                 69.000000             2.133333
# 580                  2.000000             0.416667
# 587                  2.000000             0.000000
# 596                  1.000000             0.066667
# 639                  5.333333            -0.916667
# 661                  1.000000             5.166667
#
# [45 rows x 55 columns]

# %%
hold_df.loc[478]
# Out:
# booking_dt                                                2017-10-02 12:44:00
# release_dt                                                2018-01-12 07:00:00
# booking_charge_desc                                             HOLD IMMIGRAT
# booking_charge_txt                                                        NaN
# charge_release_dt                                         2018-01-12 07:00:00
# title_txt                   Report Criteria: 10/01/2017 to 07/31/2018, Dis...
# cause_num                                                                 NaN
# jurisdiction_cd                                                           IMM
# release_disposition_desc                                          Extradition
# post_flg                                                                    N
# booking_id_hash                      1fba618ef09195b518348977fbd5a811222f6841
# gender_desc                                                              MALE
# race_desc                                                            HISPANIC
# hash_id                              894876e99f84fa1107520266685a343092ff5a28
# amer_indian_alaskan                                                         0
# asian_pacific_island                                                        0
# black                                                                       0
# hispanic                                                                    1
# unknown                                                                     0
# white                                                                       0
# female                                                                      0
# male                                                                        1
# time_detained                                                         101.761
# log_time_detained                                                     4.62263
# admin_booking                                                               0
# release_to_imm                                                              0
# cancel_detainer                                                             0
# imm_hold                                                                    1
# place_of_birth                               MEXICO (USE ONLY WHEN STATE UNK)
# country_of_birth                                                       MEXICO
# born_in_us                                                              False
# final_release_disp                                                Extradition
# charge_count                                                                3
# charge_topcount                                                             3
# category                                                                other
# type                                                                    other
# seriousness                                                                 0
# max_seriousness                                                             5
# max_charge_type                                                  public_order
# max_charge_desc                                     DUI WITH PRIOR CONVICTION
# drug                                                                        0
# other                                                                       0
# property                                                                    0
# public_order                                                                1
# sex                                                                         0
# violent                                                                     0
# felony                                                                      1
# misdemeanor                                                                 0
# total_fine                                                                  0
# paid_bail                                                               False
# log_total_fine                                                            NaN
# charge_delta                                                          2442.27
# charge_release_delta                                                        0
# longer_than_other_charge                                                 1631
# longer_than_release                                                         0
# Name: 478, dtype: object
